# %% [markdown]
# <a href="https://colab.research.google.com/github/axshay007/Matplotlib_repo/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo2.svg](data:image/svg+xml;base64,...)

# %%
import matplotlib.pyplot as plt

# %%
a=[1,2,3,4,5,6,7,8,9]
b=[1,4,9,16,25,36,49,64,81]

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 9 artists>

# %%
 a=[1,2,3,4,5,6,7]
 b=[2,19,13,24,35,7,4]

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(a,b,label='KIET')
plt.xlabel('sujects')
plt.ylabel('marks')
plt.legend() # for printing label

# %%
a=["jan","feb","mar","apr"]
income=[200,200,400,600]
saving=[20,40,60,100]
plt.bar(a,income,color="red",label="income")
plt.bar(a,saving,label="saving")
plt.legend()

# %%
plt.barh(a,saving)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(a)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
a=[1,2,3,4,5]
b=[2,4,5,6,7]
c=[3,4,5,6,7]
plt.scatter(a,b)

# %%
plt.plot(a,b,marker='o',label='cube',color='red')
plt.plot(b,c,marker='*',label='square')
plt.legend() # for label

# %%
plt.plot(a,b,marker='o',label='cube',color='red',alpha=0.1) # alpha is used to adjust the sharpness of line
plt.plot(b,c,marker='*',label='square')
plt.axis('off') # for removing axis
plt.legend()
plt.title('square vs title') # for title
plt.show()

# %%
plt.plot(a,b,marker='o',label='cube',color='red',alpha=0.1) 
plt.plot(b,c,marker='*',label='square',linestyle='dotted') # linestyle is usd to form diff kinds of line
plt.axis('off')
plt.legend()
plt.title('square vs title') # for title
plt.show()

# %%
a=["maths","chem","eng","physics"]
b=[40,56,45,23]
plt.pie(b,labels=a,autopct='%0.3f%%',shadow="true")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc42622bdd0>,
# ...
#  [Text(0.7925737390259934, 0.7627757653507069, 'maths'),
#   Text(-0.945526592075212, 0.5621205063673056, 'chem'),
#   Text(-0.1887067619849306, -1.083692649223553, 'eng'),
#   Text(0.9949506339223345, -0.46911963938588724, 'physics')],
#  [Text(0.4323129485596327, 0.4160595083731128, '24.390%'),
#   Text(-0.51574177749557, 0.3066111852912575, '34.146%'),
#   Text(-0.10293096108268941, -0.5911050813946652, '27.439%'),
#   Text(0.5427003457758187, -0.2558834396650294, '14.024%')])

# %%
a=["maths","chem","eng","physics"]
b=[40,56,45,23]
plt.pie(b,labels=a,autopct='%0.3f%%',shadow="true",explode=[0,0.5,0,0])
plt.savefig("name.png")

# %%
plt.savefig("name.png")
